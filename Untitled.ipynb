# %%
# Out:
# ...
# distributed 1.21.8 requires msgpack, which is not installed.
# grin 1.2.1 requires argparse>=1.1, which is not installed.

# %%
import pandas as pd
pd.read_csv('data_csv.csv', sep=';', skipinitialspace=True)
# Out:
#               date,price
# 0      1950-02-01,34.730
# 1      1950-03-01,34.730
# 2      1950-04-01,34.730
# 3      1950-05-01,34.730
# 4      1950-06-01,34.730
# 5      1950-07-01,34.730
# 6      1950-08-01,34.730
# 7      1950-09-01,34.730
# 8      1950-10-01,34.730
# 9      1950-11-01,34.730
# 10     1950-12-01,34.720
# 11     1951-01-01,34.720
# 12     1951-02-01,34.730
# 13     1951-03-01,34.730
# 14     1951-04-01,34.730
# 15     1951-05-01,34.730
# 16     1951-06-01,34.730
# 17     1951-07-01,34.720
# 18     1951-08-01,34.710
# 19     1951-09-01,34.710
# 20     1951-10-01,34.710
# 21     1951-11-01,34.730
# 22     1951-12-01,34.660
# 23     1952-01-01,34.490
# 24     1952-02-01,34.490
# 25     1952-03-01,34.680
# 26     1952-04-01,34.820
# 27     1952-05-01,34.730
# 28     1952-06-01,34.530
# 29     1952-07-01,34.570
# ..                   ...
# 787  2015-09-01,1124.905
# 788  2015-10-01,1157.123
# 789  2015-11-01,1088.388
# 790  2015-12-01,1068.317
# 791  2016-01-01,1095.655
# ...

# %%
import pandas as pd
import os
new_dataframe=pd.DataFrame(
    {
    "column_1":[1,2,3,4,5]
}
)
new_dataframe
# Out:
#    column_1
# 0         1
# 1         2
# 2         3
# 3         4
# 4         5

# %%
import pandas as pd
import os
print("file".format(os.getcwd()))
data=pd.read_csv("data_csv.csv")
print(type(data))
# Out:
# file
# <class 'pandas.core.frame.DataFrame'>

# %%
print(data)
# Out:
#            date     price
# 0    1950-02-01    34.730
# 1    1950-03-01    34.730
# 2    1950-04-01    34.730
# 3    1950-05-01    34.730
# 4    1950-06-01    34.730
# 5    1950-07-01    34.730
# 6    1950-08-01    34.730
# 7    1950-09-01    34.730
# 8    1950-10-01    34.730
# 9    1950-11-01    34.730
# 10   1950-12-01    34.720
# 11   1951-01-01    34.720
# 12   1951-02-01    34.730
# 13   1951-03-01    34.730
# 14   1951-04-01    34.730
# 15   1951-05-01    34.730
# 16   1951-06-01    34.730
# 17   1951-07-01    34.720
# 18   1951-08-01    34.710
# 19   1951-09-01    34.710
# 20   1951-10-01    34.710
# 21   1951-11-01    34.730
# 22   1951-12-01    34.660
# 23   1952-01-01    34.490
# 24   1952-02-01    34.490
# 25   1952-03-01    34.680
# 26   1952-04-01    34.820
# 27   1952-05-01    34.730
# 28   1952-06-01    34.530
# 29   1952-07-01    34.570
# ..          ...       ...
# 787  2015-09-01  1124.905
# 788  2015-10-01  1157.123
# 789  2015-11-01  1088.388
# ...

# %%
data.head()
# Out:
#          date  price
# 0  1950-02-01  34.73
# 1  1950-03-01  34.73
# 2  1950-04-01  34.73
# 3  1950-05-01  34.73
# 4  1950-06-01  34.73

# %%
data.tail()
# Out:
#            date     price
# 812  2017-10-01  1280.677
# 813  2017-11-01  1283.189
# 814  2017-12-01  1265.674
# 815  2018-01-01  1332.809
# 816  2018-02-01  1333.775

# %%
data.tail(2)
# Out:
#            date     price
# 815  2018-01-01  1332.809
# 816  2018-02-01  1333.775

# %%
data['date'].describe()
# Out:
# count            817
# unique           817
# top       2002-03-01
# freq               1
# Name: date, dtype: object

# %%
data['price'].max()
# Out:
# 1780.648

# %%
data['price'].min()
# Out:
# 34.49

# %%
data['date'].max()
# Out:
# '2018-02-01'

# %%
data['price'].mean()
# Out:
# 381.6186988984091

# %%
data['price'].std()
# Out:
# 418.9363261577981
